# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from scipy import io, misc
import pandas as pd

# %%
data = pd.read_csv('train/digitStruct.csv')
grouped = data.groupby(['FileName'])
for name, group in grouped:
    print name
    print group
# Out:
# 1.png
#   FileName  DigitLabel  Left  Top  Width  Height
# 0    1.png           1   246   77     81     219
# 1    1.png           9   323   81     96     219
# 10.png
#    FileName  DigitLabel  Left  Top  Width  Height
# 20   10.png           1    25    6      9      27
# 21   10.png           6    34    4     14      27
# 100.png
#     FileName  DigitLabel  Left  Top  Width  Height
# 217  100.png           1    18    1      5      22
# 218  100.png          10    23    0      9      22
# 219  100.png           9    32    0     10      22
# 1000.png
#       FileName  DigitLabel  Left  Top  Width  Height
# 2171  1000.png           1    17    1      4      18
# 2172  1000.png           3    21    1      6      18
# 10000.png
#         FileName  DigitLabel  Left  Top  Width  Height
# 22000  10000.png           1    45   20     15      29
# 22001  10000.png           5    57   23     15      29
# 22002  10000.png           3    70   23     18      29
# 10001.png
# ...

# %%
x.shape
# Out:
# (350, 741, 3)
